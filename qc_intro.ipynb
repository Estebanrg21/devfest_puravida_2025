# %% [markdown]
# <a href="https://colab.research.google.com/github/Estebanrg21/devfest_puravida_2025/blob/main/qc_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install qiskit qiskit-aer pylatexenc

# %%
import qiskit
from qiskit import QuantumCircuit
from qiskit_aer import StatevectorSimulator
import warnings
warnings.filterwarnings("ignore")

# %%
num_qubits = 4
qc = QuantumCircuit(num_qubits)

for i in range(num_qubits):
  qc.h(i)

qc.measure_all()
qc.draw("mpl")

# %%
backend = StatevectorSimulator()
job = backend.run([qc])
job_result = job.result()
print(int("".join(str(int(num)) for num in job_result.data()['statevector'].data), 2))
